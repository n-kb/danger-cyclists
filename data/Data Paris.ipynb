# %%
import pandas as pd
import numpy as np

caract_df = pd.read_csv("caracteristiques_2011.csv", encoding="latin_1")
usager_df = pd.read_csv("usagers_2011.csv", encoding="latin_1")
vehicules_df = pd.read_csv("vehicules_2011.csv", encoding="latin_1")
lieux_df = pd.read_csv("lieux_2011.csv", encoding="latin_1")

# %%
df_interim = pd.merge(caract_df, vehicules_df, how='left', left_on=['Num_Acc'], right_on = ['Num_Acc'])

# %%
df = pd.merge(df_interim, usager_df, how='left', left_on=['Num_Acc', 'num_veh'], right_on = ['Num_Acc', 'num_veh'])

# %%
df.loc[(df["dep"]==690)].groupby("com").count().sort_values("an_nais", ascending=False)
# Out:
#      Num_Acc   an  mois  jour  hrmn  lum  agg  int  atm  col   ...     place  \
# com                                                            ...
# 383      343  343   343   343   343  343  343  343  343  343   ...       285
# 387      310  310   310   310   310  310  310  310  310  310   ...       275
# 382      290  290   290   290   290  290  290  290  290  290   ...       258
# 388      257  257   257   257   257  257  257  257  257  257   ...       210
# 290      242  242   242   242   242  242  242  242  242  242   ...       227
# 259      242  242   242   242   242  242  242  242  242  242   ...       214
# 386      242  242   242   242   242  242  242  242  242  242   ...       199
# 389      240  240   240   240   240  240  240  240  240  240   ...       201
# 266      231  231   231   231   231  231  231  231  231  231   ...       194
# 256      192  192   192   192   192  192  192  192  192  192   ...       176
# ...

# %%
dep = 750
com = 1

blessé_légers = df.loc[(df["catv"] == 1) & (df["grav"] == 4) & (df["dep"] == dep)].count()["Num_Acc"]
blessé_graves = df.loc[(df["catv"] == 1) & (df["grav"] == 3) & (df["dep"] == dep)].count()["Num_Acc"]
tués = df.loc[(df["catv"] == 1) & (df["grav"] == 2) & (df["dep"] == dep)].count()["Num_Acc"]

blessé_légers, blessé_graves, tués
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7891a8ba820c> in <module>()
#       2 com = 1
#       3
# ----> 4 blessé_légers = df.loc[(df["catv"] == 1) & (df["grav"] == 4) & (df["dep"] == dep)].count()["Num_Acc"]
#       5 blessé_graves = df.loc[(df["catv"] == 1) & (df["grav"] == 3) & (df["dep"] == dep)].count()["Num_Acc"]
#       6 tués = df.loc[(df["catv"] == 1) & (df["grav"] == 2) & (df["dep"] == dep)].count()["Num_Acc"]
#
# NameError: name 'df' is not defined
